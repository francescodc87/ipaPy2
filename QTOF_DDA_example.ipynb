# %% [markdown]
# # Q-TOF example
#
# With the aim of testing the new implementation of the IPA method with a real-life dataset including fragmentation data, the dataset introduced by [Ten-Doménech et al., (2020)](https://www.mdpi.com/2218-1989/10/4/126/htm) was used. The aim of this study was to test different strategies for automated MS2 data-dependent acquisition (DDA). Here we only considered the untargeted DDA strategy as it is the most commonly used for untargeted metabolomics experiments. The experiment consisted in the analysis of human milk samples with a Agilent 6550 Spectrometer iFunnel quadrupole time-of-flight (QTOF) MS.
#
# Peak detection, integration, deconvolution, alignment and pseudospectra identification were performend with [XCMS](http://www.bioconductor.org/packages/release/bioc/html/xcms.html) and [CAMERA](https://bioconductor.org/packages/release/bioc/html/CAMERA.html) in R 3.6.1.
# The obtained peak tables and MS2 data were made available through the [Mendeley Data repository](https://data.mendeley.com/) under [DOI:10.17632/fnzbxmkv83.1](DOI:10.17632/fnzbxmkv83.1).
#
# The data was reorganised into .csv files to be compatible with the ipaPy2 package and it has made available within this library.
# The MS1 data can be found here:

# %%
import pandas as pd
import numpy as np
dfMS1 = pd.read_csv('ExampleDatasets/QTOF_DDA/dfMS1.csv')
dfMS1=dfMS1.replace('None',None)
dfMS1.head()
# Out:
#      ids  rel.ids          mzs        RTs          Ints          relationship  \
# 0  15646      763   164.920465   4.248273  19065.755811                    bp
# 1  15179     4435   164.920489  12.941176  20773.512435                    bp
# 2  10366      421   609.339623   3.241514  48622.087670          potential bp
# 3  15580      421   610.343058   3.250793  19287.414987  potential bp|isotope
# 4  15489      285  1140.835809  15.545977  19641.198670                  None
#
#   isotope.pattern charge
# 0            None   None
# 1            None   None
# 2               0      1
# 3               0      1
# 4            None   None

# %% [markdown]
# And the MS2 data can be found here:

# %%
dfMS2 = pd.read_csv('ExampleDatasets/QTOF_DDA/dfMS2.csv')
dfMS2
# Out:
#         id                                           spectrum  ev
# 0     2586  71.085:683.6281 73.0278:271.797 75.0992:492.37...  20
# 1     2586  71.0851:1917.348 73.0277:137.5172 73.0645:579....  20
# 2     4385  71.0863:157.7903 80.9472:268.5981 82.9449:282....  20
# 3     4380  71.0497:155.6042 71.0861:2613.574 72.091:152.0...  20
# 4     4385  71.081:206.8802 73.0653:142.1885 80.9478:978.4...  20
# ...    ...                                                ...  ..
# 1184  8491  71.0851:374.3737 80.9475:902.768 82.9442:163.1...  20
# 1185  3515  70.0641:130.5069 71.0134:331.6173 71.0837:202....  20
# 1186  3515  70.0289:140.5467 71.0131:142.3553 71.0607:251....  20
# 1187  8491  73.0528:151.0102 73.0636:156.0888 80.9484:387....  20
# 1188  8491  70.0409:179.9207 73.0636:175.7371 80.9473:772....  20
#
# [1189 rows x 3 columns]

# %% [markdown]
# In order to run the method this dataset, it is necessary to load the package, the MS1 database, the MS2 database and the adducts information.
# Due to its large size, the MS2 dataset included with the package is not available within the library and should must be downloaded before from [here](https://drive.google.com/file/d/15qduvtE8aSAAUCf1FE4ojcVLaTw-B2W6/view?usp=sharing).
# This MS2 database is based on data acquired from a Qexactive instrument, and it would be best to use a different one for this dataset.

# %%
from ipaPy2 import ipa
DBMS1=pd.read_csv('DB/IPA_MS1.csv')
DBMS2=pd.read_csv('DB/IPA_MS2_Qex.csv')  # make sure that this database was downladed and put in the correct folder
adducts = pd.read_csv('DB/adducts.csv')

# %% [markdown]
# As mentioned above, this study is based on the analysis of human milk samples. Therefore, it would be best to increase the 'prior knowledge' (pk) score associated with metabolites previously detected in the human milk.
# For example, we know that human milk is rich in sugars, with lactose being the major component ([Newburg, 2013](https://link.springer.com/article/10.1134/S0006297913070092)).

# %%
DBMS1['pk']=[0.9]*len(DBMS1.index)
DBMS1.iloc[171,9] = 1
DBMS1[DBMS1['id']=='C00243']
# Out:
#          id     name    formula  \
# 171  C00243  Lactose  C12H22O11
#
#                                                  inchi  smiles  RT  \
# 171  InChI=1S/C12H22O11/c13-1-3-5(15)6(16)9(19)12(2...     NaN NaN
#
#              adductsPos          adductsNeg  description   pk  MS2  \
# 171  M+H;M+Na;M+2H;2M+H  M-H;2M-H;M-2H;3M-H          NaN  1.0  NaN
#
#                                      reactions
# 171  R00503 R01100 R01678 R01680 R04393 R05166

# %% [markdown]
# A dataframe containing all possible biochemical connections among all metabolites present in the IPA_MS1.csv database has been pre-computed and it is available in the library. Using this instead of computing the connections will strongly speed up the pipeline.

# %%
Bio = pd.read_csv('DB/allBIO_reactions.csv')

# %% [markdown]
# Finally, we can run the whole pipeline with the simpleIPA() function.

# %%
annotations = ipa.simpleIPA(df=dfMS1,dfMS2=dfMS2,ionisation=1,DB=DBMS1,DBMS2=DBMS2,adductsAll=adducts,ppm=5,
                            delta_add=0.1,delta_bio=0.5,Bio=Bio,burn=1000,noits=5000,
                            CSunk=0.7,ncores=70)
# Out:
# isotopes already mapped
# computing all adducts - Parallelized ....
# 35.0 seconds elapsed
# annotating based on MS1 and MS2 information - Parallelized...
# 184.2 seconds elapsed
# computing posterior probabilities including biochemical and adducts connections
# initialising sampler ...
# Gibbs Sampler Progress Bar: 100%|██████████| 5000/5000 [20:19:34<00:00, 14.63s/it]
# parsing results ...
# Done -  73220.9 seconds elapsed

# %% [markdown]
# As an example, the annotation of few peaks is shown below.
#
#
# As mentioned before, human milk is rich in different sugars, and the mass feature shown below (id=98) is very likely to be a sugar.

# %%
annotations[98]
# Out:
#          id                                              name      formula  \
# 1    C05402                                         Melibiose  C12H22NaO11
# 2    C01742                                        Palatinose  C12H22NaO11
# 0    C08240                                       Gentiobiose  C12H22NaO11
# 3    C00243                                           Lactose  C12H22NaO11
# 27   C01970                                      beta-Lactose  C12H22NaO11
# 4    C00208                                           Maltose  C12H22NaO11
# 16   C19773  3-O-alpha-D-Mannopyranosyl-alpha-D-mannopyranose  C12H22NaO11
# 5    C01083                             alpha,alpha-Trehalose  C12H22NaO11
# 34   C00252                                        Isomaltose  C12H22NaO11
# 9    C08250                                         Sophorose  C12H22NaO11
# 28   C01728                                        Mannobiose  C12H22NaO11
# 25   C02048                                     Laminaribiose  C12H22NaO11
# 15   C19636                                          Turanose  C12H22NaO11
# 26   C01971                                      beta-Maltose  C12H22NaO11
# 10   C15548                      2-alpha-D-Glucosyl-D-glucose  C12H22NaO11
# 6    C00089                                           Sucrose  C12H22NaO11
# 32   C01235         alpha-D-Galactosyl-(1->3)-1D-myo-inositol  C12H22NaO11
# 19   C06421                                  alpha-Cellobiose  C12H22NaO11
# 21   C05400                                      Epimelibiose  C12H22NaO11
# 13   C19632                                         Kojibiose  C12H22NaO11
# 30   C01711                                        Inulobiose  C12H22NaO11
# 7    C06422                                   beta-Cellobiose  C12H22NaO11
# 24   C02964               4-O-beta-D-Glucopyranosyl-D-mannose  C12H22NaO11
# 12   C19633                                         Maltulose  C12H22NaO11
# 22   C00185                                        Cellobiose  C12H22NaO11
# 23   C04147                  alpha-D-Glucosyl-(1,3)-D-mannose  C12H22NaO11
# 33   C00897                                     alpha-Maltose  C12H22NaO11
# 18   C21336                               beta-1,2-Mannobiose  C12H22NaO11
# 17   C20236         4-O-beta-D-Mannopyranosyl-D-glucopyranose  C12H22NaO11
# 20   C04219                 alpha-D-Aldosyl beta-D-fructoside  C12H22NaO11
# 31   C01518                                          Nigerose  C12H22NaO11
# 8    C07064                                         Lactulose  C12H22NaO11
# 29   C01725                                        Levanbiose  C12H22NaO11
# 11   C18068    beta-D-Fructofuranosyl-alpha-D-mannopyranoside  C12H22NaO11
# 14   C19634                                       Melibiulose  C12H22NaO11
# 35  Unknown                                           Unknown         None
#
#    adduct        m/z charge RT range     ppm  isotope pattern score  \
# 1    M+Na  365.10543      1     None  0.6713               0.028537
# 2    M+Na  365.10543      1     None  0.6713               0.028537
# 0    M+Na  365.10543      1     None  0.6713               0.028537
# 3    M+Na  365.10543      1     None  0.6713               0.028537
# 27   M+Na  365.10543      1     None  0.6713               0.028537
# 4    M+Na  365.10543      1     None  0.6713               0.028537
# 16   M+Na  365.10543      1     None  0.6713               0.028537
# 5    M+Na  365.10543      1     None  0.6713               0.028537
# 34   M+Na  365.10543      1     None  0.6713               0.028537
# 9    M+Na  365.10543      1     None  0.6713               0.028537
# 28   M+Na  365.10543      1     None  0.6713               0.028537
# 25   M+Na  365.10543      1     None  0.6713               0.028537
# 15   M+Na  365.10543      1     None  0.6713               0.028537
# 26   M+Na  365.10543      1     None  0.6713               0.028537
# 10   M+Na  365.10543      1     None  0.6713               0.028537
# 6    M+Na  365.10543      1     None  0.6713               0.028537
# 32   M+Na  365.10543      1     None  0.6713               0.028537
# 19   M+Na  365.10543      1     None  0.6713               0.028537
# 21   M+Na  365.10543      1     None  0.6713               0.028537
# 13   M+Na  365.10543      1     None  0.6713               0.028537
# 30   M+Na  365.10543      1     None  0.6713               0.028537
# 7    M+Na  365.10543      1     None  0.6713               0.028537
# 24   M+Na  365.10543      1     None  0.6713               0.028537
# 12   M+Na  365.10543      1     None  0.6713               0.028537
# 22   M+Na  365.10543      1     None  0.6713               0.028537
# 23   M+Na  365.10543      1     None  0.6713               0.028537
# 33   M+Na  365.10543      1     None  0.6713               0.028537
# 18   M+Na  365.10543      1     None  0.6713               0.028537
# 17   M+Na  365.10543      1     None  0.6713               0.028537
# 20   M+Na  365.10543      1     None  0.6713               0.028537
# 31   M+Na  365.10543      1     None  0.6713               0.028537
# 8    M+Na  365.10543      1     None  0.6713               0.028537
# 29   M+Na  365.10543      1     None  0.6713               0.028537
# 11   M+Na  365.10543      1     None  0.6713               0.028537
# 14   M+Na  365.10543      1     None  0.6713               0.028537
# 35   None       None   None     None  5.0000               0.001217
#
#    fragmentation pattern score     prior      post  post Gibbs  \
# 1                     0.994367  0.028457  0.039000     0.05150
# 2                      0.99417  0.028457  0.038993     0.04500
# 0                     0.994705  0.028457  0.039014     0.03850
# 3                          0.7  0.028457  0.030505     0.03500
# 27                         0.7  0.028457  0.027455     0.03200
# 4                     0.729812  0.028457  0.028624     0.03200
# 16                         0.7  0.028457  0.027455     0.03100
# 5                     0.700893  0.028457  0.027490     0.03025
# 34                         0.7  0.028457  0.027455     0.03025
# 9                          0.7  0.028457  0.027455     0.02950
# 28                         0.7  0.028457  0.027455     0.02900
# 25                         0.7  0.028457  0.027455     0.02875
# 15                         0.7  0.028457  0.027455     0.02875
# 26                         0.7  0.028457  0.027455     0.02875
# 10                         0.7  0.028457  0.027455     0.02875
# 6                          0.7  0.028457  0.027455     0.02875
# 32                         0.7  0.028457  0.027455     0.02825
# 19                         0.7  0.028457  0.027455     0.02825
# 21                         0.7  0.028457  0.027455     0.02700
# 13                         0.7  0.028457  0.027455     0.02675
# 30                         0.7  0.028457  0.027455     0.02625
# 7                          0.7  0.028457  0.027455     0.02625
# 24                         0.7  0.028457  0.027455     0.02575
# 12                         0.7  0.028457  0.027455     0.02525
# 22                         0.7  0.028457  0.027455     0.02525
# 23                         0.7  0.028457  0.027455     0.02475
# 33                         0.7  0.028457  0.027455     0.02450
# 18                         0.7  0.028457  0.027455     0.02400
# 17                         0.7  0.028457  0.027455     0.02400
# 20                         0.7  0.028457  0.027455     0.02375
# 31                         0.7  0.028457  0.027455     0.02375
# 8                          0.7  0.028457  0.027455     0.02325
# 29                         0.7  0.028457  0.027455     0.02300
# 11                         0.7  0.028457  0.027455     0.02150
# 14                         0.7  0.028457  0.027455     0.01925
# 35                         0.7  0.003993  0.000182     0.00150
#
#     chi-square pval
# 1      8.709218e-09
# 2      8.709218e-09
# 0      8.709218e-09
# 3      8.709218e-09
# 27     8.709218e-09
# 4      8.709218e-09
# 16     8.709218e-09
# 5      8.709218e-09
# 34     8.709218e-09
# 9      8.709218e-09
# 28     8.709218e-09
# 25     8.709218e-09
# 15     8.709218e-09
# 26     8.709218e-09
# 10     8.709218e-09
# 6      8.709218e-09
# 32     8.709218e-09
# 19     8.709218e-09
# 21     8.709218e-09
# 13     8.709218e-09
# 30     8.709218e-09
# 7      8.709218e-09
# 24     8.709218e-09
# 12     8.709218e-09
# 22     8.709218e-09
# 23     8.709218e-09
# 33     8.709218e-09
# 18     8.709218e-09
# 17     8.709218e-09
# 20     8.709218e-09
# 31     8.709218e-09
# 8      8.709218e-09
# 29     8.709218e-09
# 11     8.709218e-09
# 14     8.709218e-09
# 35     8.709218e-09

# %% [markdown]
# Human milk has been reported to be a source of sphingolipids such as sphingomyelin ([De Cas et al., 2020](https://translational-medicine.biomedcentral.com/articles/10.1186/s12967-020-02641-0)).
# The two mass features shown below are very likely to be sphingolipids:

# %%
annotations[837]
# Out:
#                       id           name      formula adduct         m/z  \
# 0  EMBL-MCF_spec32425x_1  SPHINGOMYELIN  C41H84N2O6P    M+H  731.606151
# 1                Unknown        Unknown         None   None        None
#
#   charge RT range       ppm isotope pattern score fragmentation pattern score  \
# 0      1     None  0.663757                  None                    0.860111
# 1   None     None  5.000000                  None                         0.7
#
#       prior      post  post Gibbs  chi-square pval
# 0  0.877047  0.887492       0.815     1.058444e-47
# 1  0.122953  0.112508       0.185     1.058444e-47

# %%
annotations[1983]
# Out:
#         id              name    formula adduct        m/z charge RT range  \
# 0   C12144  Phytosphingosine  C18H40NO3    M+H  318.30027      1     None
# 1  Unknown           Unknown       None   None       None   None     None
#
#         ppm isotope pattern score fragmentation pattern score     prior  \
# 0 -0.831674                  None                    0.842381  0.874864
# 1  5.000000                  None                         0.7  0.125136
#
#        post  post Gibbs  chi-square pval
# 0  0.883341     0.98075     4.371479e-82
# 1  0.116659     0.01925     4.371479e-82

# %% [markdown]
# Alarmingly, the presence of phtalates has also been reported in human breast milk ([Fromme et al., 2011](https://pubmed.ncbi.nlm.nih.gov/21406311/)).
# The most likely annotation for the mass feature shown below (id=255) is Bis(2-ethylhexyl)phthalate (DEHP).

# %%
annotations[255]
# Out:
#            id                                          name     formula  \
# 0      C03690                    Bis(2-ethylhexyl)phthalate    C24H39O4
# 4      C15375                                Apocholic acid    C24H39O4
# 9   NPA027102    2-hydroxy-6-(12-oxoheptadecyl)benzoic acid    C24H39O4
# 8   NPA018676                                 Antroquinonol    C24H39O4
# 10  NPA032143                                   Phomopene B    C24H39O4
# 6   NPA011157                     Delta-8'-Merulinic acid A    C24H39O4
# 7   NPA016979               12α-Hydroxy-3-ketocholanic acid    C24H39O4
# 2      C14227                          Di-n-octyl phthalate    C24H39O4
# 1      C11637  3alpha,12alpha-Dihydroxy-5beta-chol-6-enoate    C24H39O4
# 3      C14577                          Diisooctyl phthalate    C24H39O4
# 5   NPA001332                              Merulinic acid B    C24H39O4
# 11    Unknown                                       Unknown        None
# 12  NPA010528                              Hygrophorone B16  C22H40NaO4
# 13     C16696                                Dolichotheline  C20H35N6O2
# 14  NPA029307                              Strepimidazole E  C20H35N6O2
#
#    adduct         m/z charge RT range       ppm  isotope pattern score  \
# 0     M+H  391.284286      1     None  0.837601               0.090775
# 4     M+H  391.284286      1     None  0.837601               0.090775
# 9     M+H  391.284286      1     None  0.837601               0.090775
# 8     M+H  391.284286      1     None  0.837601               0.090775
# 10    M+H  391.284286      1     None  0.837601               0.090775
# 6     M+H  391.284286      1     None  0.837601               0.090775
# 7     M+H  391.284286      1     None  0.837601               0.090775
# 2     M+H  391.284286      1     None  0.837601               0.090775
# 1     M+H  391.284286      1     None  0.837601               0.090775
# 3     M+H  391.284286      1     None  0.837601               0.090775
# 5     M+H  391.284286      1     None  0.837601               0.090775
# 11   None        None   None     None  5.000000               0.000570
# 12   M+Na  391.281878      1     None  6.991572               0.000827
# 13   2M+H    391.2816      1     None  7.700545               0.000037
# 14   2M+H    391.2816      1     None  7.700545               0.000037
#
#    fragmentation pattern score     prior          post  post Gibbs  \
# 0                      0.99118  0.089423  1.240212e-01     0.14825
# 4                          0.7  0.089423  8.758737e-02     0.09675
# 9                          0.7  0.089423  8.758737e-02     0.09500
# 8                          0.7  0.089423  8.758737e-02     0.08875
# 10                         0.7  0.089423  8.758737e-02     0.08850
# 6                          0.7  0.089423  8.758737e-02     0.08450
# 7                          0.7  0.089423  8.758737e-02     0.08450
# 2                          0.7  0.089423  8.758737e-02     0.08050
# 1                          0.7  0.089423  8.758737e-02     0.07925
# 3                          0.7  0.089423  8.758737e-02     0.07850
# 5                          0.7  0.089423  8.758737e-02     0.06950
# 11                         0.7  0.012801  8.746344e-05     0.00600
# 12                         0.7  0.001894  1.690397e-05     0.00000
# 13                         0.7  0.000823  3.269529e-07     0.00000
# 14                         0.7  0.000823  3.269529e-07     0.00000
#
#     chi-square pval
# 0               0.0
# 4               0.0
# 9               0.0
# 8               0.0
# 10              0.0
# 6               0.0
# 7               0.0
# 2               0.0
# 1               0.0
# 3               0.0
# 5               0.0
# 11              0.0
# 12              0.0
# 13              0.0
# 14              0.0

# %% [markdown]
# The whole annotation file can be saved.

# %%
import pickle
file = open("ExampleDatasets/QTOF_DDA/annotations.pickle", "wb")
pickle.dump(annotations, file)
file.close()
